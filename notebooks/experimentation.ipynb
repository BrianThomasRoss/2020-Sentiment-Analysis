# %%
import tweepy

# %%
from environs import Env

env = Env()
env.read_env()

TWITTER_KEY = env.str('TWITTER_KEY')
TWITTER_SECRET = env.str('TWITTER_SECRET')

auth = tweepy.AppAuthHandler(TWITTER_KEY, TWITTER_SECRET)

api = tweepy.API(auth)

# %%
# !poetry add pandas numpy
# Out:
# Using version ^1.1.1 for pandas
# Using version ^1.19.1 for numpy
#
# Updating dependencies
# Resolving dependencies... (1.7s)
#
# Writing lock file
#
#
# Package operations: 3 installs, 0 updates, 0 removals
#
#   - Installing numpy (1.19.1)
#   - Installing pytz (2020.1)
#   - Installing pandas (1.1.1)

# %%
import datetime as dt

import numpy as np
import pandas as pd

trump_hashtags = [


tweet_attributes = ['id',
                    'account',
                    'account_screenname',
                    'account_followers',
                    'account_following',
                    'account_age_days',
                    'account_description',
                    'is_retweet',
                    'original_author',
                    'tweeted_on',
                    'count_retweeted',
                    'count_favorited',
                    'hashtags',
                    'tweet_text'
                   ]

tweets = {attr: [] for attr in tweet_attributes}


for tweet in tweepy.Cursor(api.search, q='#maga').items(200):    
    
    tweets['id'].append(tweet.id)
    tweets["account"].append(tweet.author.name)
    tweets["account_screenname"].append(tweet.user.screen_name)
    tweets["account_followers"].append(tweet.author.followers_count)
    tweets["account_following"].append(tweet.author.friends_count)
    tweets["account_age_days"].append(get_account_age(
               tweet.author.created_at
               ))
    tweets["account_description"].append(parse_profile_description(
                   tweet.author.description
               ))
    tweets["is_retweet"].append(is_retweet(tweet.text))
    tweets["original_author"].append(get_original_author(tweet))
    tweets["tweeted_on"].append(tweet.created_at)
    tweets["count_retweeted"].append(tweet.retweet_count)
    tweets["count_favorited"].append(tweet.favorite_count)
    tweets["hashtags"].append(get_hashtags(tweet))
    tweets["tweet_text"].append(tweet.text)

# %%
def get_account_age(creation_date):
    return abs(
        (dt.datetime.today() - tweet.author.created_at)
    ).days

def parse_profile_description(pattern):
    return np.NaN if pattern == '' else pattern

def is_retweet(pattern):
    return 1 if pattern[:2] == 'RT' else 0

def get_original_author(tweet):
    if is_retweet(tweet.text):
        return tweet._json['retweeted_status']['user']['screen_name']
    else:
        return tweet.author.screen_name
    
def get_hashtags(tweet):
    hashtags = tweet.entities.get('hashtags')
    if len(hashtags) == 0:
        return np.NaN
    else:
        return ", ".join([tag['text'] for tag in hashtags])

# %%
pd.DataFrame(tweets)
# Out:
#                       id                  account account_screenname  \
# 0    1297367121698201601            Robert Newton        robbynewton
# 1    1297367112881704961                    Jason      Jason39336330
# 2    1297367109790392321                 khun Tom          tgclark56
# 3    1297367108423213056            Bill Nieporte       billnieporte
# 4    1297367098516275200  Injustice is everywhere        DispatchesF
# ..                   ...                      ...                ...
# 195  1297365627993075714  🌺That Sarcastic Ginger🌺          White2to4
# 196  1297365618539343872          Laura Gawlinski     GawlinskiLaura
# 197  1297365618233085953          Sheila Seaglass     SheilaSeaglass
# 198  1297365616047738880                  くろさきいちご       sakamoto_kou
# 199  1297365615901126657              Bobby Duley        duley_bobby
#
#      account_followers  account_following  account_age_days  \
# 0                  298                744              4156
# 1                  346                542               114
# 2                 6556               7251              3316
# 3                  226                688              4113
# 4                   20                  6               156
# ..                 ...                ...               ...
# 195              25879              17808               263
# 196                242               1773              1969
# 197                 35                166              1272
# 198                117                166              3503
# 199               3446               4962               198
#
#                                    account_description  is_retweet  \
# 0    oceanographer at @LamontEarth, Arctic climate,...           1
# 1    Vc me segue,eu te sigo🇧🇷🏳️‍🌈🇺🇸 Criei ódio da e...           0
# 2    Bisexual, Retired Military, Retired Photojourn...           1
# 3    Husband, Father, Improv and Stand Up Comic, Ho...           0
# 4    bringing visibility to and calling out those p...           0
# ..                                                 ...         ...
# 195  I kneel for God only✝️ CONSERVATIVE PATRIOT🇺🇸H...           1
# 196                                                NaN           1
# 197                                                NaN           1
# 198                                         catcatcat…           1
# 199  American first ,Constitutional conservative, m...           1
#
#      original_author          tweeted_on  count_retweeted  count_favorited  \
# 0     BryanDawsonUSA 2020-08-23 02:56:40              195                0
# 1      Jason39336330 2020-08-23 02:56:38                0                0
# 2    TheDemCoalition 2020-08-23 02:56:37             1253                0
# 3       billnieporte 2020-08-23 02:56:37                0                0
# 4        DispatchesF 2020-08-23 02:56:34                0                0
# ..               ...                 ...              ...              ...
# 195            Lybio 2020-08-23 02:50:44              163                0
# 196  TheDemCoalition 2020-08-23 02:50:42             1256                0
# 197   bryanstone1984 2020-08-23 02:50:41                5                0
# 198  realDonaldTrump 2020-08-23 02:50:41            32528                0
# 199            Lybio 2020-08-23 02:50:41              179                0
#
#                                       hashtags  \
# 0                                         MAGA
# 1    BolsonaroOrgulhoDoBrasil, MAGA, Trump2020
# 2                                         MAGA
# 3                                          NaN
# 4                                        trump
# ..                                         ...
# 195                                        NaN
# 196                                       MAGA
# 197                   maga, defundpublicschool
# 198                                       MAGA
# 199                                        NaN
#
#                                             tweet_text
# 0    RT @BryanDawsonUSA: Ignorant, Trump-loving, #M...
# 1    Bolsonaro 👏🏼👏🏼 #BolsonaroOrgulhoDoBrasil #MAGA...
# 2    RT @TheDemCoalition: Since he's tweeting about...
# 3    @firefly909 In the last election cycle @realDo...
# 4    @realDonaldTrump Just stop   Let it go #trump....
# ..                                                 ...
# 195  RT @Lybio: 💥POW💥Pres @realDonaldTrump Sleepy @...
# 196  RT @TheDemCoalition: Since he's tweeting about...
# 197  RT @bryanstone1984: Says it all #maga #defundp...
# 198  RT @realDonaldTrump: THANK YOU PENNSYLVANIA! #...
# 199  RT @Lybio: @realDonaldTrump We Ended @BarackOb...
#
# [200 rows x 14 columns]

# %%
import datetime as dt

# %%
tweet.favorite_count
# Out:
# 0

# %%
dir(tweet)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_api',
#  '_json',
#  'author',
#  'contributors',
#  'coordinates',
#  'created_at',
#  'destroy',
#  'entities',
#  'favorite',
#  'favorite_count',
#  'favorited',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'metadata',
#  'parse',
#  'parse_list',
#  'place',
#  'retweet',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'retweets',
#  'source',
#  'source_url',
#  'text',
#  'truncated',
#  'user']
